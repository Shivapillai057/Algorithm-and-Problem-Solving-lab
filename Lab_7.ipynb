# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivapillai057/Algorithm-and-Problem-Solving-lab/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy Knapsack Problem (Fractional)
# In this lab, we explore the Fractional Knapsack Problem, a fundamental optimization problem that demonstrates the Greedy Algorithmic Paradigm.
# We will implement it using greedy selection (based on value-to-weight ratio) and analyze its time and space complexity.

# %% [markdown]
# - Created by Dr. Ajay

# %% [markdown]
# # Problem Definition
# Given a set of
# n
# n items, each with:
# Value vi
# Weight wi
# A knapsack with maximum capacity **W**
#
# Goal: maximize total value that can be put in the knapsack.
# Constraint: You may take fractions of items.
#
# Greedy Strategy:
#
# *  Sort items by decreasing ratio vi/wi
# *  Select items fully until knapsack is full.
# *  Take fraction of the next item if capacity remains.

# %%
import numpy as np
import pandas as pd

# %%
#write code for the above problem
w=[10, 20, 30, 5]
v=[60, 100, 120, 50]
r=[]*len(w)
W=50



for i in range(len(w)):
    r.append(v[i]/w[i])


data = pd.DataFrame({'Weight': w, 'Value': v, 'Ratio': r})
print(data)
data2 = data.sort_values(by='Ratio', ascending=False)

data2.reset_index(drop=True, inplace=True)
print(data2)
w =0
profit = 0
i= 0
while(w<W):
  profit = profit +data2.iloc[i,1]
  w = w+data2.iloc[i,0]
  i=i+1


if(w > W):
  i=i-1
  profit = profit -data2.iloc[i,1]
  w = w-data2.iloc[i,0]
  i=i+1

if(w != W):
 i=i-1
 profit = profit + (data2.iloc[i,1]/data2.iloc[i,0])*(W-w)
 w = W


print('profit =', profit)
# Out:
#    Weight  Value  Ratio
# 0      10     60    6.0
# 1      20    100    5.0
# 2      30    120    4.0
# 3       5     50   10.0
#    Weight  Value  Ratio
# 0       5     50   10.0
# 1      10     60    6.0
# 2      20    100    5.0
# 3      30    120    4.0
# profit = 270.0

# %% [markdown]
# In this lab, we implement Huffman Coding, a greedy algorithm used for lossless data compression.
# It assigns variable-length binary codes to input symbols based on their frequencies, ensuring that more frequent symbols receive shorter codes and less frequent symbols receive longer codes.
#
# This algorithm constructs a binary tree (Huffman Tree) where each leaf node represents a character, and the path from the root to a leaf gives the character’s binary code.
#
# Use:
# Huffman Tree Construction using a Min-Priority Queue (Min-Heap).
# Code generation for each character.
# Encoding and decoding using the generated Huffman codes.
# Complexity analysis and comparison with fixed-length encoding.
#
# # Pseudocode:
# 1. Create a leaf node for each character and insert all nodes into a
# 2. min-heap by frequency.
#    *  While the heap has more than one node:
#    * Extract two nodes with the lowest frequencies.
#    * Create a new internal node with frequency = sum of the two.
#    *  Set the two extracted nodes as left and right children.
#    *  Insert the new node back into the min-heap.
# 3. The remaining node is the root of the Huffman Tree.
#
# 4. Traverse the tree:
#    * Assign 0 for left edge and 1 for right edge.
#    * The resulting paths from root to leaves give Huffman codes.

# %%
# write code for above
import pandas as pd
import heapq


text = "this is my lab exercise"


freq_df = pd.Series(list(text)).value_counts().reset_index()
freq_df.columns = ['Character', 'Frequency']


class Node:
    def __init__(self, char, freq):
        self.char = char
        self.freq = freq
        self.left = None
        self.right = None

    def __lt__(self, other):
        return self.freq < other.freq

heap = []
for _, row in freq_df.iterrows():
    heapq.heappush(heap, Node(row['Character'], row['Frequency']))


while len(heap) > 1:
    left = heapq.heappop(heap)
    right = heapq.heappop(heap)

    merged = Node(None, left.freq + right.freq)
    merged.left = left
    merged.right = right

    heapq.heappush(heap, merged)

root = heap[0]


codes = {}

def generate_codes(node, current_code=""):
    if node is None:
        return
    if node.char is not None:
        codes[node.char] = current_code
    generate_codes(node.left, current_code + "0")
    generate_codes(node.right, current_code + "1")

generate_codes(root)

encoded_text = "".join([codes[ch] for ch in text])


def decode(encoded, root):
    result = ""
    current = root
    for bit in encoded:
        if bit == '0':
            current = current.left
        else:
            current = current.right
        if current.char is not None:
            result += current.char
            current = root
    return result

decoded_text = decode(encoded_text, root)


print("\nHuffman Codes:\n", codes)
print("\nEncoded Text:\n", encoded_text)
print("\nDecoded Text:\n", decoded_text)
# Out:
# Huffman Codes:
#  {' ': '000', 'm': '001', 'e': '010', 'g': '0110', 'u': '0111', 'f': '100', 'n': '1010', 'a': '1011', 'x': '11000', 'p': '11001', 'h': '11010', 'd': '11011', 'o': '11100', 'i': '11101', 'c': '11110', 'l': '11111'}
#
# Encoded Text:
#  1101001111001000011011101000011110111001101111101101001100000101100010110011100111111010
#
# Decoded Text:
#  huffman coding example
